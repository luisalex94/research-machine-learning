# %% [markdown]
# # Chapter 003
#
# Data - What Is It Really?
#
# Hands-On Data Preprocessing in Python

# %% [markdown]
# ## What is data?
#
# * Higher-Lever conventions and understandings (HLCUs).
# * Pyramid: Data, Information, Knowledge, and Wisdom (DIKW).
# * Pyramid: Data, Dataset, Patterns, Action (DDPA).
# * Pyramid: Data, Dataset, Visualization, Wisdom (DDVW).
#
# #### DIKW Pyramid
#
# 1. Future - Wisdom
# 2. Past - Knowlege (Judgment to get Wisom)
# 3. Past - Information (Cognition to get Knowledge)
# 4. Past - Data (Processing to get Information)
#
#
# * Data: A collection of symbols - cannot answer any questions.
# * Informacion: Procesed data - can answer the questions who, when, where and what.
# * Knowledge: Descriptive application of Information - can answer the question how.
# * Wisdom: Embodiment of Knowledge and appreciation of why.
#
# #### DDPA Pyramid (Updated DIKW for ML and AI)
#
# 1. Future - Action
# 2. Past - Patterns (Risk Analysis to get Action)
# 3. Past - Dataset (Mine to get Patterns)
# 4. Past - Data (Preprocess to get Datasets)
#
# * Data: All posible data from across all the data resources.
# * Dataset: A relevant collection of data selected from all the available data sources, cleaned and organized for the next step.
# * Patterns: The interesting and useful trens and relationships within the dataset.
# * Action: The decision made, which is informed by the recognized patterns.
#
# Transacctional steps between the four elements of the DDAP pyramid:
#
# * Preprocess: To select the relevant data and prepare it fot the next step.
# * Mine: Applying data mining algorithms to the data in search of patterns.
# * Risk analysis: The step to consider the uncertainty of the recognized patterns and arrive at a decision.
#
# #### DDVW Pyramid (Updated DIKW and DDPA for data analytics)
#
# 1. Future - Wisdom
# 2. Past - Visualization (Judgment to get Wisdom)
# 3. Past - Dataset (Analyze to get Visualization)
# 4. Past - Data (Preprocess to get Datasets)
#
# * Data: All posible data from across all the data resources.
# * Dataset: A relevant collection of data selected from all the available data sources, cleaned and organized for the next step.
# * Visualization: The comprehensible presentation of what has been found in the dataset.
# * Wisdom: Embodiment of knowledge and appreciation of why (the same as Wisdom in DIKW).
#
# #### Data analyst:
#
# 1. Explore the dataset.
# 2. Test the hypothesis.
# 3. Report the relevant findings.
#
# ### The three Vs of big data
#
# 1. Volume, variety and velocity.

# %% [markdown]
# ## The most universal data structure - a table
#
# The structure of a table have to keywords:
#
# 1. Data objects (rows).
# 2. Data attributes (columns).

# %% [markdown]
# ## Types of data values
#
# The are four major types of values from analytics stanspoints:
#
# * Data attributes:
#     1. Numerical:
#         * Ratio-Scaled.
#         * Interval-Scaled.
#     2. Categorical:
#         * Ordinal.
#         * Nominal:
#             * Non-Binary.
#             * Binary:
#                 * Symmetric.
#                 * Asymmetric.
#
# [Nominal and Ordinal] -> Categorical (or qualitative)
#
# [Interval-Scaled and Ratio-Scaled] -> Numerical (quantitative)
#
# * Nominal attributes:
#     * Simple set of letters and symbols that act as a name of the object or a category of the object.
#     * Examples: Hair color, skin color, eye color, marital status or occupation.
#     * They do not contain any other information than just names.
# * Ordinal attributes:
#     * More information that pertains to some types of order.
#     * Examples: Level of education, professional rankings, or survey rates.
# * Interval-scaled attributes:
#     * These attributes contain more information than ordinal attributes. We also move from symbols and categories to numbers.
#     * Examples: Height, weight, temperature.
# * Ratio-scaled attributes:
#     * It removes the incapanility to multiply or divide values for interval-scaled attributes.
#     * Examples: Monthly income.
# * Binary attributes:
#     * Nominal attributes with only two possibilities.
#     * Example: Sex.
#     * Symmetric binary attributes carries the same level of importance for our analysis like sex.
#     * Asymmetric binary attributes happens less frequently and is normally more important, like COVID test, where the positive results happen less often but are more important in our analysis.
#
# The following table presents a mapping of attribute (value) types between analytics and programing perspectives:
#
# | Analytic perspective | Programming perspective |
# |-|-|
# | Nominal attributes - binary | Booleans or strings |
# | Nominal attributes - non-binary | Booleans or strings |
# | Ordinal attributes | Booleans or strings |
# | Ordinal attributes | Integers |
# | Interval-scaled attributes | Integers or floating points |
# | Ration-scaled attributes | Integers or floating points |

# %% [markdown]
# ## Information versus pattern
#
# * Information is the value variation of one attribute across the data objects of a dataset.
# * Pattern is about the value variation of more than one attribute across the data objects of a dataset.
#
# Correlation coefficient to investigate data redundancy: Correlation coefficient value falls between -1 and 1. When the value is close to zero, it means the two attributes are not showing similar information. When the correlation coefficient between two numerical attributes is closer to both ends of the spectrum (-1 or +1), it shows that the two attributes are showing similar statistical information and perhaps one of them is redundant. When two attributes have a significant and positive correlation coefficient (greater than 0.7), that means if the value of one attribute increases the value of the other attribute will also increase.
